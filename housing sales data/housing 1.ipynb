# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("data.csv")

# %%
from sklearn.preprocessing import LabelEncoder
data.ocean_proximity=LabelEncoder().fit_transform(data.ocean_proximity)

# %%
data=data.drop(["longitude","latitude"],axis=1)

# %%
data["constant"]=pd.DataFrame(np.ones(len(data)))

# %%
train=data[:int(0.7*len(data))]
test=data[int(0.7*len(data)):]

# %%
trainy=train["median_house_value"]
testy=test["median_house_value"]

# %%
trainx=train.drop(["median_house_value"],axis=1)
testx=test.drop(["median_house_value"],axis=1)

# %%
theta=np.zeros(8)

# %%
theta=pd.DataFrame(theta)

# %%
trainx["total_bedrooms"]=trainx["total_bedrooms"].fillna(trainx["total_bedrooms"].median())
testx["total_bedrooms"]=testx["total_bedrooms"].fillna(trainx["total_bedrooms"].median())

# %%
trainx.columns=[0,1,2,3,4,5,6,7]

# %%
testx.columns=[0,1,2,3,4,5,6,7]

# %%
y_pred=np.dot(trainx,theta)

# %%
m=trainy.size

# %%
print(y_pred.size)
print(trainy.size)
print(trainx[0].size)
# Out:
# 14447
# 14447
# 14447

# %%
d_theta=(1/m)*np.dot(trainx,(y_pred-trainy))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 d_theta=(1/m)*np.dot(trainx,(y_pred-trainy))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:2102, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2098 @final
#    2099 def __array_ufunc__(
#    2100     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2101 ):
# -> 2102     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:273, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     270 kwargs = _standardize_out_kwarg(**kwargs)
#     272 # for binary ops, use our custom dunder methods
# --> 273 result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#     274 if result is not NotImplemented:
#     275     return result
#
# File ops_dispatch.pyx:113, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:198, in OpsMixin.__rsub__(self, other)
#     196 @unpack_zerodim_and_defer("__rsub__")
#     197 def __rsub__(self, other):
# --> 198     return self._arith_method(other, roperator.rsub)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:5819, in Series._arith_method(self, other, op)
#    5817 def _arith_method(self, other, op):
#    5818     self, other = self._align_for_op(other)
# -> 5819     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/base.py:1383, in IndexOpsMixin._arith_method(self, other, op)
#    1380 with np.errstate(all="ignore"):
#    1381     result = ops.arithmetic_op(lvalues, rvalues, op)
# -> 1383 return self._construct_result(result, name=res_name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:5915, in Series._construct_result(self, result, name)
#    5912 # TODO: result should always be ArrayLike, but this fails for some
#    5913 #  JSONArray tests
#    5914 dtype = getattr(result, "dtype", None)
# -> 5915 out = self._constructor(result, index=self.index, dtype=dtype, copy=False)
#    5916 out = out.__finalize__(self)
#    5918 # Set the result's name after __finalize__ is called because __finalize__
#    5919 #  would set it back to self.name
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:512, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     510         data = data.copy()
#     511 else:
# --> 512     data = sanitize_array(data, index, dtype, copy)
#     514     manager = get_option("mode.data_manager")
#     515     if manager == "block":
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/construction.py:658, in sanitize_array(data, index, dtype, copy, allow_2d)
#     655             subarr = cast(np.ndarray, subarr)
#     656             subarr = maybe_infer_to_datetimelike(subarr)
# --> 658 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     660 if isinstance(subarr, np.ndarray):
#     661     # at this point we should have dtype be None or subarr.dtype == dtype
#     662     dtype = cast(np.dtype, dtype)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/construction.py:717, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     715     if allow_2d:
#     716         return result
# --> 717     raise ValueError(
#     718         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     719     )
#     720 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     721     # i.e. NumpyEADtype("O")
#     723     result = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (14447, 14447) instead

# %%
for i in range(1000):
    y_pred=np.dot(trainx,theta)
    m=trainy.size
