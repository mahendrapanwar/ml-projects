# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("train.csv",header=0)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from sklearn.preprocessing import LabelEncoder
data.Embarked=LabelEncoder().fit_transform(data.Embarked)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Embarked
# 0      0         A/5 21171   7.2500   NaN         2
# 1      0          PC 17599  71.2833   C85         0
# 2      0  STON/O2. 3101282   7.9250   NaN         2
# 3      0            113803  53.1000  C123         2
# 4      0            373450   8.0500   NaN         2

# %%
data.Sex=LabelEncoder().fit_transform(data.Sex)

# %%
data["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
trainx=data.drop(['Survived','Name','Ticket','Cabin'],axis=1)

# %%
trainy=data[['PassengerId','Survived']]

# %%
trainy.head()
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
log_reg=LogisticRegression()
rnd_clf=RandomForestClassifier()
svm_clf=SVC()

voting_clf=VotingClassifier(
    estimators=[('lr',log_reg), ('rf', rnd_clf), ('svc', svm_clf)], 
    voting='hard')

# %%
voting_clf.fit(trainx, trainy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 voting_clf.fit(trainx, trainy)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_voting.py:320, in VotingClassifier.fit(self, X, y, sample_weight)
#     315 if self.voting not in ("soft", "hard"):
#     316     raise ValueError(
#     317         "Voting must be 'soft' or 'hard'; got (voting=%r)" % self.voting
#     318     )
# --> 320 self.le_ = LabelEncoder().fit(y)
#     321 self.classes_ = self.le_.classes_
#     322 transformed_y = self.le_.transform(y)
#
# File ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:98, in LabelEncoder.fit(self, y)
#      85 def fit(self, y):
#      86     """Fit label encoder.
#      87
#      88     Parameters
#    (...)
#      96         Fitted label encoder.
#      97     """
# ---> 98     y = column_or_1d(y, warn=True)
#      99     self.classes_ = _unique(y)
#     100     return self
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:1038, in column_or_1d(y, warn)
#    1029         warnings.warn(
#    1030             "A column-vector y was passed when a 1d array was"
#    1031             " expected. Please change the shape of y to "
#    (...)
#    1034             stacklevel=2,
#    1035         )
#    1036     return np.ravel(y)
# -> 1038 raise ValueError(
#    1039     "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1040 )
#
# ValueError: y should be a 1d array, got an array of shape (891, 2) instead.
